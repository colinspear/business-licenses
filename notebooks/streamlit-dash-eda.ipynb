# %%
import pandas as pd

from matplotlib import pyplot as plt

# %%
df = pd.read_csv('../data/2013-2021-clean.csv')
# Out:
# /Users/colinspear/.venv/business_licenses/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3155: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#    FOLDERYEAR  LicenceRSN LicenceNumber  LicenceRevisionNumber  \
# 0          14     2118891     14-106531                      0
# 1          14     2118895     14-106535                      0
# 2          14     2118901     14-106541                      0
# 3          14     2118906     14-106546                      0
# 4          14     2118912     14-106552                      0
#
#                       BusinessName BusinessTradeName                Status  \
# 0              Gill Framing Co Ltd               NaN                Issued
# 1        ITC Residential BC II Inc               NaN              Inactive
# 2  Quoc Khanh Nguyen (Quoc Nguyen)  K & H Renovation  Gone Out of Business
# 3        Evershine Enterprises Ltd               NaN                Issued
# 4           Zhao Peng Li (Zhao Li)               NaN                Issued
#
#                   IssuedDate ExpiredDate BusinessType  ... FeePaid  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463884 entries, 0 to 463883
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             463884 non-null  int64
#  1   FOLDERYEAR             463884 non-null  int64
#  2   LicenceRSN             463884 non-null  int64
#  3   LicenceNumber          463884 non-null  object
#  4   LicenceRevisionNumber  463884 non-null  int64
#  5   BusinessName           463884 non-null  object
#  6   BusinessTradeName      197293 non-null  object
#  7   Status                 463884 non-null  object
#  8   IssuedDate             390083 non-null  object
#  9   ExpiredDate            389916 non-null  object
#  10  BusinessType           463884 non-null  object
#  11  BusinessSubType        262700 non-null  object
#  12  Unit                   129530 non-null  object
#  13  UnitType               129515 non-null  object
# ...

# %%
len(df['id'].unique())
# Out:
# 149440

# %%
df.groupby('id')['FOLDERYEAR'].plot.hist()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-4b454f1a05ee> in <module>
# ----> 1 df.groupby('id')['FOLDERYEAR'].plot.hist()
#
# ~/.venv/business_licenses/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in attr(*args, **kwargs)
#     471                 return getattr(self.plot, name)(*args, **kwargs)
#     472
# --> 473             return self._groupby.apply(f)
#     474
#     475         return attr
#
# ~/.venv/business_licenses/lib/python3.9/site-packages/pandas/core/groupby/generic.py in apply(self, func, *args, **kwargs)
#     219     )
#     220     def apply(self, func, *args, **kwargs):
# --> 221         return super().apply(func, *args, **kwargs)
#     222
#     223     @doc(_agg_template, examples=_agg_examples_doc, klass="Series")
#
# ...
